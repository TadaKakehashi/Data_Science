# %% [markdown]
# ## Standard Library Overview

# %%
import array
arr = array.array('i',[1,2,3,4,5]) # i -> integer
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
## Random
import random
print(random.randint(1,10)) # provides random integer between number specified
print(random.choice(['apple','banana','cherry']))
# Out:
# 5
# banana

# %%
### OS -> File and Directory Operations
import os
print(os.getcwd())
# Out:
# d:\Python\Importing_Modules

# %%
os.mkdir('test_dir')

# %%
## High level operations on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization with Json
import json
data = {'name':'Tada','age':23}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

json_dir = json.loads(json_str)
print(json_dir)
print(type(json_dir))
# Out:
# {"name": "Tada", "age": 23}
# <class 'str'>
# {'name': 'Tada', 'age': 23}
# <class 'dict'>

# %%
## CSV

import csv 

with open('example.csv', mode='w', newline ='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Tada',23])

with open('example.csv', mode = 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Tada', '23']

# %%
## datetime
from datetime import datetime, timedelta

now=datetime.now()
print(now)

yesterday = now-timedelta(days=1) #going one day back
print(yesterday)
# Out:
# 2026-02-25 10:19:18.247235
# 2026-02-24 10:19:18.247235

# %%
## time
import time
print(time.time())
time.sleep(12)
print(time.time())
# Out:
# 1771995034.088849
# 1771995046.0893536

# %%
## Regular expression
import re
pattern = r'\d+'
text = 'There are 123 Tada 456'
match = re.search(pattern,text)
print(match.group())
# Out:
# 456
