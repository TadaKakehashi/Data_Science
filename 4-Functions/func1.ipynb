# %% [markdown]
# ## Functions
#
# A function is a block of code that performs a specific task. Functions help in organizing code, reusing code, and improving readability

# %%
def function_name(parameters):
    "Docstring" #comment what the function does
    #Function body
    return expression

# %%
def check_even(num):
    """This Function finds even or odd"""
    if num%2 == 0:
        print(f'{num} is an Even Number!')
    else:
        print(f'{num} is an Odd Number!')

check_even(12)
# Out:
# 12 is an Even Number!

# %%
### Functions with Multiple Parameters

def add(a,b):
    return a+b

add(10,20)
# Out:
# 30

# %%
## Default Parameters

def greet(name = "Minion"):
    print(f'Konichiwa! {name}')

greet("Tada")
greet()
# Out:
# Konichiwa! Tada
# Konichiwa! Minion

# %%
### Variable Length Arguments

## Positional and Keyword arguments

# Positional arguments
def print_number(*args):    
    for numbers in args:
        print(numbers)


# Keywords Arguments -> all the parameters will be in key and value pairs
def print_details(**kwargs):
    for key, value in kwargs.items():
        print(f'{key} : {value}')

# %%
print_number(1,2,3,4,5,6,"Tada")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# Tada

# %%
print_details(name = "Tada", age=23, country = "India")
# Out:
# name : Tada
# age : 23
# country : India

# %%
def print_details(*args, **kwargs):
    for val in args:
        print(f'Positional Argument: {val}')
    for key, value in kwargs.items():
        print(f'{key} : {value}')



print_details(1,2,3,4,5,"Tada", name="Aryan",age=23,height=6.1,sex="male")
# Out:
# Positional Argument: 1
# Positional Argument: 2
# Positional Argument: 3
# Positional Argument: 4
# Positional Argument: 5
# Positional Argument: Tada
# name : Aryan
# age : 23
# height : 6.1
# sex : male

# %%
## Return Statements

def multiply(a,b):
    return a*b,a+b,a-b #Returning multiple parameters

multiply(2,3)
# Out:
# (6, 5, -1)

# %% [markdown]
# ##### Examples

# %%
# Example 1: Temperature Conversion

def convert_temp(temp, unit):
    """This function converts temp between celsius and Fahrenheit"""
    if unit == 'C':
        return temp * 9/5 + 32 
    elif unit == 'F':
        return (temp-32)*5/9 
    else:
        return none


print(convert_temp(25,'C'))
print(convert_temp(77,'F'))
# Out:
# 77.0
# 25.0

# %%
# Example 2: Password Strength Checker

def password_checker(password):
    """This function checks if the password is strong or not"""
    if len(password) < 8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in '!@#$%^&*()_+' for char in password):
        return False
    return True

password_checker("Str0ngPwd!")
# Out:
# True

# %%
password_checker("Aryan@2020")
# Out:
# True

# %%
#Example 3: Calculate the Total Cost of Items in a Shopping Cart

def calculate_total_cost(cart):
    total = 0

    for item in cart:
        total += item['price'] * item['quantity']
    return total

cart = [
    {'name':'Apple','price':0.5,'quantity':4},
    {'name':'Banana','price':0.3,'quantity':5},
    {'name':'Kiwi','price':0.9,'quantity':8}
]

total = calculate_total_cost(cart)
print(total)
# Out:
# 10.7

# %%
def check_palindrome(string):
    rev_string = string[::-1]

    if rev_string == string:
        print("Palindrome")
    else:
        print("Not a Palindrome")


check_palindrome("racecar")
# Out:
# Palindrome
