# %% [markdown]
# ### Copying a Function

# %%
def hello():
    print("Hello World")

copy_function = hello   # copying the function

copy_function()

# %% [markdown]
# ### Closure
# A closure is a function inside another function that remembers the variables from the outer function, even after the outer function has finished executing.

# %%
def outer_function(msg):
    
    def inner_function():
        print(msg)   # inner function remembers msg
    
    return inner_function

closure_example = outer_function("Hello Closure")
closure_example()

# %% [markdown]
# ### Decorators
# A decorator is a function that modifies the behavior of another function without changing its code.
# Decorators use the @ symbol.
#
# decorator → wrapper → original function

# %% [markdown]
# ### Wrapper Function
# A wrapper is a function inside a decorator that wraps around the original function to add extra behavior.

# %%
def my_decorator(func):

    def wrapper():
        print("Something before the function runs")

        func()  # calling original function

        print("Something after the function runs")

    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello!")

say_hello()
# Out:
# Something before the function runs
# Hello!
# Something after the function runs
